# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/성현/PODA
# Out:
# /content/drive/MyDrive/성현/PODA

# %%
! pip install pickle5
! pip install tqdm
! pip install ftfy
! pip install regex
! pip install git+https://github.com/openai/CLIP.git
# Out:
# Collecting pickle5
#   Downloading pickle5-0.0.11.tar.gz (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.1/132.1 kB 3.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pickle5
#   Building wheel for pickle5 (setup.py) ... done
#   Created wheel for pickle5: filename=pickle5-0.0.11-cp310-cp310-linux_x86_64.whl size=255319 sha256=b71fdb18965f3eb1cebead32e50688dd00764fa94e6ebace18dc1e551d8ae86e
#   Stored in directory: /root/.cache/pip/wheels/7d/14/ef/4aab19d27fa8e58772be5c71c16add0426acf9e1f64353235c
# Successfully built pickle5
# Installing collected packages: pickle5
# Successfully installed pickle5-0.0.11
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.4)
# Collecting ftfy
#   Downloading ftfy-6.2.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /usr/local/lib/python3.10/dist-packages (from ftfy) (0.2.13)
# Installing collected packages: ftfy
# Successfully installed ftfy-6.2.0
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (2024.5.15)
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-clw7g59y
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-clw7g59y
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ftfy in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (6.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (24.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (4.66.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (2.3.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (0.18.1+cu121)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /usr/local/lib/python3.10/dist-packages (from ftfy->clip==1.0) (0.2.13)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (1.13.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->clip==1.0)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->clip==1.0)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->clip==1.0)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->clip==1.0)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->clip==1.0)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->clip==1.0)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->clip==1.0)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->clip==1.0)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->clip==1.0)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch->clip==1.0)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->clip==1.0)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (2.3.1)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->clip==1.0)
#   Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 62.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->clip==1.0) (1.25.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->clip==1.0) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->clip==1.0) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->clip==1.0) (1.3.0)
# Building wheels for collected packages: clip
#   Building wheel for clip (setup.py) ... done
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369490 sha256=4973580b561a7e8dbe04214330050ddcc46820246da2ff42d5da72e55d4ad287
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fe7jauxi/wheels/da/2b/4c/d6691fa9597aac8bb85d2ac13b112deb897d5b50f5ad9a37e4
# Successfully built clip
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, clip
# Successfully installed clip-1.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.82 nvidia-nvtx-cu12-12.1.105

# %%
! python3 PIN_aug.py --dataset 'cityscapes' --data_root '/content/drive/MyDrive/PODA/datasets/data/Cityscapes'  --save_dir '/content/drive/MyDrive/성현/datasets/stastics_save(augment)' --resize_feat --total_it 100 --domain_desc 'driving in snow'
# Out:
# 2024-07-24 08:43:33.093698: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-24 08:43:33.093743: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-24 08:43:33.095132: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-24 08:43:33.102723: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-24 08:43:34.203907: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Dataset: cityscapes, Train set: 2975, Val set: 500
# 0
# 100
# 1
# 100
# 2
# 100
# 3
# 100
# 4
# 100
# 5
# 100
# 6
# 100
# 7
# 100
# 8
# 100
# 9
# 100
# 10
# 100
# 11
# 100
# 12
# 100
# 13
# 100
# 14
# 100
# 15
# 100
# 16
# 100
# 17
# 100
# 18
# 100
# 19
# 100
# 20
# 100
# 21
# 100
# 22
# 100
# 23
# 100
# 24
# 100
# 25
# 100
# 26
# 100
# 27
# 100
# 28
# 100
# 29
# 100
# 30
# 100
# 31
# 100
# 32
# 100
# 33
# 100
# 34
# 100
# 35
# 100
# 36
# 100
# 37
# 100
# 38
# 100
# 39
# 100
# 40
# 100
# 41
# 100
# 42
# 100
# 43
# 100
# 44
# 100
# 45
# 100
# 46
# 100
# 47
# 100
# 48
# 100
# 49
# 100
# 50
# 100
# 51
# 100
# 52
# 100
# 53
# 100
# 54
# 100
# 55
# 100
# 56
# 100
# 57
# 100
# 58
# 100
# 59
# 100
# 60
# 100
# 61
# 100
# 62
# 100
# 63
# 100
# 64
# 100
# 65
# 100
# 66
# 100
# 67
# 100
# 68
# 100
# 69
# 100
# 70
# 100
# 71
# 100
# 72
# 100
# 73
# 100
# 74
# 100
# 75
# 100
# 76
# 100
# 77
# 100
# 78
# 100
# 79
# 100
# 80
# 100
# 81
# 100
# 82
# 100
# 83
# 100
# 84
# 100
# 85
# 100
# 86
# 100
# 87
# 100
# 88
# 100
# 89
# 100
# 90
# 100
# 91
# 100
# 92
# 100
# 93
# 100
# 94
# 100
# 95
# 100
# 96
# 100
# 97
# 100
# 98
# 100
# 99
# 100
# 100
# 100
# 101
# 100
# 102
# 100
# 103
# 100
# 104
# 100
# 105
# 100
# 106
# 100
# 107
# 100
# 108
# 100
# 109
# 100
# 110
# 100
# 111
# 100
# 112
# 100
# 113
# 100
# 114
# 100
# 115
# 100
# 116
# 100
# 117
# 100
# 118
# 100
# 119
# 100
# 120
# 100
# 121
# 100
# 122
# 100
# 123
# 100
# 124
# 100
# 125
# 100
# 126
# 100
# 127
# 100
# 128
# 100
# 129
# 100
# 130
# 100
# 131
# 100
# 132
# 100
# 133
# 100
# 134
# 100
# 135
# 100
# 136
# 100
# 137
# 100
# 138
# 100
# 139
# 100
# 140
# 100
# 141
# 100
# 142
# 100
# 143
# 100
# 144
# 100
# 145
# 100
# 146
# 100
# 147
# 100
# 148
# 100
# 149
# 100
# 150
# 100
# 151
# 100
# 152
# 100
# 153
# 100
# 154
# 100
# 155
# 100
# 156
# 100
# 157
# 100
# 158
# 100
# 159
# 100
# 160
# 100
# 161
# 100
# 162
# 100
# 163
# 100
# 164
# 100
# 165
# 100
# 166
# 100
# 167
# 100
# 168
# 100
# 169
# 100
# 170
# 100
# 171
# 100
# 172
# 100
# 173
# 100
# 174
# 100
# 175
# 100
# 176
# 100
# 177
# 100
# 178
# 100
# 179
# 100
# 180
# 100
# 181
# 100
# 182
# 100
# 183
# 100
# 184
# 100
# 185
# 100
# torch.Size([15, 256, 1, 1])
# torch.Size([15, 256, 1, 1])

# %%
! python3 main.py --dataset 'cityscapes' --data_root '/content/drive/MyDrive/PODA/datasets/data/Cityscapes' --ckpt '/content/drive/MyDrive/PODA/CS_source.pth' --batch_size 8 --lr 0.01 --ckpts_path adapted --freeze_BB --train_aug --total_itrs 2000  --path_mu_sig '/content/drive/MyDrive/성현/datasets/stastics_save(augment)'
# Out:
# 2024-07-24 10:02:05.837007: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-24 10:02:05.837062: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-24 10:02:05.838427: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-24 10:02:05.845811: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-24 10:02:06.914161: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Device: cuda
# Dataset: cityscapes, Train set: 2975, Val set: 500
# Model restored from /content/drive/MyDrive/PODA/CS_source.pth
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Epoch 1, Itrs 10/2000, Loss=0.570067
# Epoch 1, Itrs 20/2000, Loss=0.622279
# Epoch 1, Itrs 30/2000, Loss=0.469739
# Epoch 1, Itrs 40/2000, Loss=0.534940
# Epoch 1, Itrs 50/2000, Loss=0.397601
# Epoch 1, Itrs 60/2000, Loss=0.588603
# Epoch 1, Itrs 70/2000, Loss=0.337636
# Epoch 1, Itrs 80/2000, Loss=0.409010
# Epoch 1, Itrs 90/2000, Loss=0.388910
# Epoch 1, Itrs 100/2000, Loss=0.379175
# Epoch 1, Itrs 110/2000, Loss=0.371886
# Epoch 1, Itrs 120/2000, Loss=0.459847
# Epoch 1, Itrs 130/2000, Loss=0.367254
# Epoch 1, Itrs 140/2000, Loss=0.373723
# Epoch 1, Itrs 150/2000, Loss=0.385324
# Epoch 1, Itrs 160/2000, Loss=0.383984
# Epoch 1, Itrs 170/2000, Loss=0.371233
# Epoch 1, Itrs 180/2000, Loss=0.434435
# Epoch 1, Itrs 190/2000, Loss=0.330825
# Epoch 1, Itrs 200/2000, Loss=0.347136
# Epoch 1, Itrs 210/2000, Loss=0.399888
# Epoch 1, Itrs 220/2000, Loss=0.390135
# Epoch 1, Itrs 230/2000, Loss=0.371179
# Epoch 1, Itrs 240/2000, Loss=0.411207
# Epoch 1, Itrs 250/2000, Loss=0.421516
# Epoch 1, Itrs 260/2000, Loss=0.385657
# Epoch 1, Itrs 270/2000, Loss=0.351109
# Epoch 1, Itrs 280/2000, Loss=0.380215
# Epoch 1, Itrs 290/2000, Loss=0.399593
# Epoch 1, Itrs 300/2000, Loss=0.389756
# Epoch 1, Itrs 310/2000, Loss=0.352562
# Epoch 1, Itrs 320/2000, Loss=0.363266
# Epoch 1, Itrs 330/2000, Loss=0.340200
# Epoch 1, Itrs 340/2000, Loss=0.370500
# Epoch 1, Itrs 350/2000, Loss=0.356746
# Epoch 1, Itrs 360/2000, Loss=0.392294
# Epoch 1, Itrs 370/2000, Loss=0.300736
# Epoch 2, Itrs 380/2000, Loss=0.304332
# Epoch 2, Itrs 390/2000, Loss=0.323485
# Epoch 2, Itrs 400/2000, Loss=0.374421
# Epoch 2, Itrs 410/2000, Loss=0.311038
# Epoch 2, Itrs 420/2000, Loss=0.369874
# Epoch 2, Itrs 430/2000, Loss=0.372245
# Epoch 2, Itrs 440/2000, Loss=0.393949
# Epoch 2, Itrs 450/2000, Loss=0.382939
# Epoch 2, Itrs 460/2000, Loss=0.327453
# Epoch 2, Itrs 470/2000, Loss=0.331973
# Epoch 2, Itrs 480/2000, Loss=0.337086
# Epoch 2, Itrs 490/2000, Loss=0.315493
# Epoch 2, Itrs 500/2000, Loss=0.347086
# Epoch 2, Itrs 510/2000, Loss=0.334211
# Epoch 2, Itrs 520/2000, Loss=0.329831
# Epoch 2, Itrs 530/2000, Loss=0.450150
# Epoch 2, Itrs 540/2000, Loss=0.333419
# Epoch 2, Itrs 550/2000, Loss=0.298915
# Epoch 2, Itrs 560/2000, Loss=0.294876
# Epoch 2, Itrs 570/2000, Loss=0.302204
# Epoch 2, Itrs 580/2000, Loss=0.383966
# Epoch 2, Itrs 590/2000, Loss=0.354316
# Epoch 2, Itrs 600/2000, Loss=0.352015
# Epoch 2, Itrs 610/2000, Loss=0.319883
# Epoch 2, Itrs 620/2000, Loss=0.365019
# Epoch 2, Itrs 630/2000, Loss=0.306591
# Epoch 2, Itrs 640/2000, Loss=0.368571
# Epoch 2, Itrs 650/2000, Loss=0.342588
# Epoch 2, Itrs 660/2000, Loss=0.338348
# Epoch 2, Itrs 670/2000, Loss=0.385178
# Epoch 2, Itrs 680/2000, Loss=0.356357
# Epoch 2, Itrs 690/2000, Loss=0.344907
# Epoch 2, Itrs 700/2000, Loss=0.340253
# Epoch 2, Itrs 710/2000, Loss=0.342525
# Epoch 2, Itrs 720/2000, Loss=0.298894
# Epoch 2, Itrs 730/2000, Loss=0.325439
# Epoch 2, Itrs 740/2000, Loss=0.298687
# Epoch 3, Itrs 750/2000, Loss=0.295054
# Epoch 3, Itrs 760/2000, Loss=0.331140
# Epoch 3, Itrs 770/2000, Loss=0.347823
# Epoch 3, Itrs 780/2000, Loss=0.298643
# Epoch 3, Itrs 790/2000, Loss=0.325268
# Epoch 3, Itrs 800/2000, Loss=0.297321
# Epoch 3, Itrs 810/2000, Loss=0.334564
# Epoch 3, Itrs 820/2000, Loss=0.274885
# Epoch 3, Itrs 830/2000, Loss=0.411511
# Epoch 3, Itrs 840/2000, Loss=0.304028
# Epoch 3, Itrs 850/2000, Loss=0.294048
# Epoch 3, Itrs 860/2000, Loss=0.307618
# Epoch 3, Itrs 870/2000, Loss=0.348437
# Epoch 3, Itrs 880/2000, Loss=0.355937
# Epoch 3, Itrs 890/2000, Loss=0.343950
# Epoch 3, Itrs 900/2000, Loss=0.308717
# Epoch 3, Itrs 910/2000, Loss=0.323600
# Epoch 3, Itrs 920/2000, Loss=0.304409
# Epoch 3, Itrs 930/2000, Loss=0.310366
# Epoch 3, Itrs 940/2000, Loss=0.297441
# Epoch 3, Itrs 950/2000, Loss=0.332441
# Epoch 3, Itrs 960/2000, Loss=0.322755
# Epoch 3, Itrs 970/2000, Loss=0.305076
# Epoch 3, Itrs 980/2000, Loss=0.350919
# Epoch 3, Itrs 990/2000, Loss=0.368939
# Epoch 3, Itrs 1000/2000, Loss=0.292272
# Epoch 3, Itrs 1010/2000, Loss=0.314648
# Epoch 3, Itrs 1020/2000, Loss=0.354707
# Epoch 3, Itrs 1030/2000, Loss=0.305834
# Epoch 3, Itrs 1040/2000, Loss=0.385366
# Epoch 3, Itrs 1050/2000, Loss=0.261857
# Epoch 3, Itrs 1060/2000, Loss=0.302369
# Epoch 3, Itrs 1070/2000, Loss=0.294868
# Epoch 3, Itrs 1080/2000, Loss=0.308192
# Epoch 3, Itrs 1090/2000, Loss=0.392227
# Epoch 3, Itrs 1100/2000, Loss=0.328759
# Epoch 3, Itrs 1110/2000, Loss=0.305985
# Epoch 4, Itrs 1120/2000, Loss=0.309896
# Epoch 4, Itrs 1130/2000, Loss=0.323779
# Epoch 4, Itrs 1140/2000, Loss=0.300957
# Epoch 4, Itrs 1150/2000, Loss=0.287469
# Epoch 4, Itrs 1160/2000, Loss=0.324173
# Epoch 4, Itrs 1170/2000, Loss=0.316425
# Epoch 4, Itrs 1180/2000, Loss=0.304530
# Epoch 4, Itrs 1190/2000, Loss=0.340501
# Epoch 4, Itrs 1200/2000, Loss=0.310560
# Epoch 4, Itrs 1210/2000, Loss=0.300475
# Epoch 4, Itrs 1220/2000, Loss=0.336890
# Epoch 4, Itrs 1230/2000, Loss=0.286672
# Epoch 4, Itrs 1240/2000, Loss=0.331581
# Epoch 4, Itrs 1250/2000, Loss=0.294579
# Epoch 4, Itrs 1260/2000, Loss=0.330355
# Epoch 4, Itrs 1270/2000, Loss=0.311730
# Epoch 4, Itrs 1280/2000, Loss=0.304647
# Epoch 4, Itrs 1290/2000, Loss=0.348002
# Epoch 4, Itrs 1300/2000, Loss=0.276425
# Epoch 4, Itrs 1310/2000, Loss=0.362536
# Epoch 4, Itrs 1320/2000, Loss=0.386404
# Epoch 4, Itrs 1330/2000, Loss=0.291021
# Epoch 4, Itrs 1340/2000, Loss=0.330925
# Epoch 4, Itrs 1350/2000, Loss=0.311823
# Epoch 4, Itrs 1360/2000, Loss=0.278452
# Epoch 4, Itrs 1370/2000, Loss=0.326807
# Epoch 4, Itrs 1380/2000, Loss=0.348649
# Epoch 4, Itrs 1390/2000, Loss=0.307758
# Epoch 4, Itrs 1400/2000, Loss=0.308727
# Epoch 4, Itrs 1410/2000, Loss=0.330371
# Epoch 4, Itrs 1420/2000, Loss=0.294571
# Epoch 4, Itrs 1430/2000, Loss=0.301393
# Epoch 4, Itrs 1440/2000, Loss=0.361951
# Epoch 4, Itrs 1450/2000, Loss=0.316355
# Epoch 4, Itrs 1460/2000, Loss=0.275413
# Epoch 4, Itrs 1470/2000, Loss=0.282101
# Epoch 4, Itrs 1480/2000, Loss=0.321220
# Epoch 5, Itrs 1490/2000, Loss=0.284987
# Epoch 5, Itrs 1500/2000, Loss=0.269410
# Epoch 5, Itrs 1510/2000, Loss=0.310805
# Epoch 5, Itrs 1520/2000, Loss=0.276761
# Epoch 5, Itrs 1530/2000, Loss=0.292175
# Epoch 5, Itrs 1540/2000, Loss=0.312265
# Epoch 5, Itrs 1550/2000, Loss=0.315827
# Epoch 5, Itrs 1560/2000, Loss=0.300213
# Epoch 5, Itrs 1570/2000, Loss=0.299759
# Epoch 5, Itrs 1580/2000, Loss=0.316333
# Epoch 5, Itrs 1590/2000, Loss=0.331395
# Epoch 5, Itrs 1600/2000, Loss=0.288602
# Epoch 5, Itrs 1610/2000, Loss=0.308847
# Epoch 5, Itrs 1620/2000, Loss=0.315184
# Epoch 5, Itrs 1630/2000, Loss=0.267561
# Epoch 5, Itrs 1640/2000, Loss=0.264830
# Epoch 5, Itrs 1650/2000, Loss=0.284608
# Epoch 5, Itrs 1660/2000, Loss=0.312091
# Epoch 5, Itrs 1670/2000, Loss=0.275653
# Epoch 5, Itrs 1680/2000, Loss=0.307276
# Epoch 5, Itrs 1690/2000, Loss=0.281425
# Epoch 5, Itrs 1700/2000, Loss=0.358184
# Epoch 5, Itrs 1710/2000, Loss=0.355254
# Epoch 5, Itrs 1720/2000, Loss=0.289045
# Epoch 5, Itrs 1730/2000, Loss=0.323314
# Epoch 5, Itrs 1740/2000, Loss=0.367771
# Epoch 5, Itrs 1750/2000, Loss=0.298317
# Epoch 5, Itrs 1760/2000, Loss=0.283754
# Epoch 5, Itrs 1770/2000, Loss=0.273719
# Epoch 5, Itrs 1780/2000, Loss=0.289634
# Epoch 5, Itrs 1790/2000, Loss=0.296713
# Epoch 5, Itrs 1800/2000, Loss=0.308252
# Epoch 5, Itrs 1810/2000, Loss=0.314671
# Epoch 5, Itrs 1820/2000, Loss=0.312349
# Epoch 5, Itrs 1830/2000, Loss=0.292669
# Epoch 5, Itrs 1840/2000, Loss=0.290887
# Epoch 5, Itrs 1850/2000, Loss=0.298598
# Epoch 6, Itrs 1860/2000, Loss=0.292534
# Epoch 6, Itrs 1870/2000, Loss=0.306849
# Epoch 6, Itrs 1880/2000, Loss=0.309718
# Epoch 6, Itrs 1890/2000, Loss=0.253404
# Epoch 6, Itrs 1900/2000, Loss=0.276887
# Epoch 6, Itrs 1910/2000, Loss=0.316779
# Epoch 6, Itrs 1920/2000, Loss=0.284567
# Epoch 6, Itrs 1930/2000, Loss=0.267585
# Epoch 6, Itrs 1940/2000, Loss=0.332766
# Epoch 6, Itrs 1950/2000, Loss=0.319159
# Epoch 6, Itrs 1960/2000, Loss=0.320273
# Epoch 6, Itrs 1970/2000, Loss=0.286902
# Epoch 6, Itrs 1980/2000, Loss=0.311531
# Epoch 6, Itrs 1990/2000, Loss=0.279913
# Epoch 6, Itrs 2000/2000, Loss=0.271270
# Model saved as adapted/adapted_deeplabv3plus_resnet_clip_cityscapes.pth

# %%
! python3 main.py --dataset 'ACDC' --data_root '/content/drive/MyDrive/PODA/datasets/data/ACDC' --ckpt '/content/drive/MyDrive/성현/PODA/adapted/adapted_deeplabv3plus_resnet_clip_cityscapes.pth' --test_only --val_batch_size 1 --ACDC_sub 'snow'
# Out:
# 2024-07-24 10:44:35.825357: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-24 10:44:35.825417: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-24 10:44:35.826990: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-24 10:44:35.834300: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-24 10:44:36.934665: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Device: cuda
# /content/drive/MyDrive/PODA/datasets/data/ACDC/rgb_anon/snow/train
# /content/drive/MyDrive/PODA/datasets/data/ACDC/rgb_anon/snow/val
# Dataset: ACDC, Train set: 400, Val set: 100
# Model restored from /content/drive/MyDrive/성현/PODA/adapted/adapted_deeplabv3plus_resnet_clip_cityscapes.pth
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# 100% 100/100 [00:32<00:00,  3.11it/s]
#
# Overall Acc: 0.858297
# Mean Acc: 0.574701
# FreqW Acc: 0.767739
# Mean IoU: 0.435578
#
# 0.435577675644685
# {0: 0.7564052877838723, 1: 0.3225239220635086, 2: 0.7495471227971298, 3: 0.25060162086913984, 4: 0.27612497418137594, 5: 0.3501108733586026, 6: 0.559555085626163, 7: 0.4494634128179327, 8: 0.8325349748609344, 9: 0.139871764426502, 10: 0.9437975068011187, 11: 0.48184599195760835, 12: 0.008638824222365579, 13: 0.6717501266346573, 14: 0.261092008996665, 15: 0.017354785872366434, 16: 0.47388420189142877, 17: 0.412730821468083, 18: 0.31814253061956194}

# %%
! python3 main.py --dataset 'ACDC' --data_root '/content/drive/MyDrive/PODA/datasets/data/ACDC' --ckpt '/content/drive/MyDrive/성현/PODA/adapted/adapted_deeplabv3plus_resnet_clip_cityscapes.pth' --test_only --val_batch_size 1 --ACDC_sub 'rain'
# Out:
# 2024-07-24 10:45:21.277123: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-24 10:45:21.277171: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-24 10:45:21.278437: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-24 10:45:21.285586: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-24 10:45:22.347810: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Device: cuda
# /content/drive/MyDrive/PODA/datasets/data/ACDC/rgb_anon/rain/train
# /content/drive/MyDrive/PODA/datasets/data/ACDC/rgb_anon/rain/val
# Dataset: ACDC, Train set: 400, Val set: 100
# Model restored from /content/drive/MyDrive/성현/PODA/adapted/adapted_deeplabv3plus_resnet_clip_cityscapes.pth
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# 100% 100/100 [00:33<00:00,  2.98it/s]
#
# Overall Acc: 0.879545
# Mean Acc: 0.613807
# FreqW Acc: 0.804801
# Mean IoU: 0.419399
#
# 0.41939919524428015
# {0: 0.7715629034016169, 1: 0.33561409157086375, 2: 0.7680705601839218, 3: 0.18972156870844606, 4: 0.238383498545496, 5: 0.3866640878278809, 6: 0.5245596368883011, 7: 0.4348647206574899, 8: 0.8763855716145633, 9: 0.40859902561477346, 10: 0.9650803377630681, 11: 0.49009482399131044, 12: 0.048544296323054376, 13: 0.6563203194101439, 14: 0.17168720806596416, 15: 0.07000126843283648, 16: 0.25308499714898114, 17: 0.1695755546789206, 18: 0.20977023881369083}

# %%
! python3 main.py --dataset 'ACDC' --data_root '/content/drive/MyDrive/PODA/datasets/data/ACDC' --ckpt '/content/drive/MyDrive/성현/PODA/adapted/adapted_deeplabv3plus_resnet_clip_cityscapes.pth' --test_only --val_batch_size 1 --ACDC_sub 'night'
# Out:
# 2024-07-24 10:46:07.283885: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-24 10:46:07.283934: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-24 10:46:07.285260: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-24 10:46:07.292316: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-24 10:46:08.354555: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Device: cuda
# /content/drive/MyDrive/PODA/datasets/data/ACDC/rgb_anon/night/train
# /content/drive/MyDrive/PODA/datasets/data/ACDC/rgb_anon/night/val
# Dataset: ACDC, Train set: 400, Val set: 106
# Model restored from /content/drive/MyDrive/성현/PODA/adapted/adapted_deeplabv3plus_resnet_clip_cityscapes.pth
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# 100% 106/106 [00:36<00:00,  2.88it/s]
# /content/drive/MyDrive/성현/PODA/metrics/stream_metrics.py:66: RuntimeWarning: invalid value encountered in divide
#   acc_cls = np.diag(hist) / hist.sum(axis=1)
#
# Overall Acc: 0.573437
# Mean Acc: 0.375959
# FreqW Acc: 0.406858
# Mean IoU: 0.224205
#
# 0.2242053057935316
# {0: 0.7637145963981112, 1: 0.24089625543518825, 2: 0.43034481823212645, 3: 0.08824954830871178, 4: 0.20650088601035693, 5: 0.27921358294286003, 6: 0.2510838430628983, 7: 0.2330954342686905, 8: 0.38792598349019985, 9: 0.05863505115343041, 10: 0.07475531318613805, 11: 0.3019149081940258, 12: 0.11374072765807135, 13: 0.3848610106122442, 14: 0.06230293121569543, 15: 0.0, 16: 0.2015169380675248, 17: 0.06926853833564145, 18: 0.1118804435051867}
