# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/성현/PODA
# Out:
# /content/drive/MyDrive/성현/PODA

# %%
! pip install pickle5
! pip install tqdm
! pip install ftfy
! pip install regex
! pip install git+https://github.com/openai/CLIP.git
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.1/132.1 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pickle5: filename=pickle5-0.0.11-cp310-cp310-linux_x86_64.whl size=255317 sha256=df2181a71036d622e9cfa83b32be5f1d78f971949131a3fe115b6a89660368b5
#   Stored in directory: /root/.cache/pip/wheels/7d/14/ef/4aab19d27fa8e58772be5c71c16add0426acf9e1f64353235c
# Successfully built pickle5
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 4.0 MB/s eta 0:00:00
# ...
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-7t9r_fes
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-7t9r_fes
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...

# %%
! python3 PIN_aug.py --dataset 'cityscapes' --data_root '/content/drive/MyDrive/PODA/datasets/data/Cityscapes'  --save_dir '/content/drive/MyDrive/성현/datasets/stastics_save' --resize_feat --total_it 100
# Out:
# 2024-07-11 07:43:20.076511: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-11 07:43:20.153656: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-11 07:43:20.153714: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-11 07:43:20.155399: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
! python3 main.py --dataset 'cityscapes' --data_root '/content/drive/MyDrive/PODA/datasets/data/Cityscapes' --ckpt '/content/drive/MyDrive/PODA/CS_source.pth' --batch_size 8 --lr 0.01 --ckpts_path adapted --freeze_BB --train_aug --total_itrs 2000  --path_mu_sig '/content/drive/MyDrive/성현/datasets/stastics_save(parameter Loss experiment)'
# Out:
# 2024-07-10 15:52:40.712459: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-10 15:52:40.763002: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-10 15:52:40.763050: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-10 15:52:40.764466: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
! python3 main.py --dataset 'ACDC' --data_root '/content/drive/MyDrive/PODA/datasets/data/ACDC' --ckpt '/content/drive/MyDrive/성현/PODA/adapted/adapted_deeplabv3plus_resnet_clip_cityscapes.pth' --test_only --val_batch_size 1 --ACDC_sub 'rain'
# Out:
# 2024-07-01 16:46:25.573371: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-01 16:46:25.625142: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-01 16:46:25.625194: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-01 16:46:25.626524: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
! python3 main.py --dataset 'ACDC' --data_root '/content/drive/MyDrive/PODA/datasets/data/ACDC' --ckpt '/content/drive/MyDrive/성현/PODA/adapted/adapted_deeplabv3plus_resnet_clip_cityscapes.pth' --test_only --val_batch_size 1 --ACDC_sub 'snow'
# Out:
# 2024-07-10 16:47:56.687176: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-10 16:47:56.738643: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-10 16:47:56.738687: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-10 16:47:56.740153: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
! python3 main.py --dataset 'ACDC' --data_root '/content/drive/MyDrive/PODA/datasets/data/ACDC' --ckpt '/content/drive/MyDrive/성현/PODA/adapted/adapted_deeplabv3plus_resnet_clip_cityscapes.pth' --test_only --val_batch_size 1 --ACDC_sub 'night'
# Out:
# 2024-07-01 16:48:53.866965: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-01 16:48:53.917366: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-01 16:48:53.917416: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-01 16:48:53.918750: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
