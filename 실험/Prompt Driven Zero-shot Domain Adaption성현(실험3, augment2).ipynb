# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/PODA성현
# Out:
# /content/drive/MyDrive/Colab Notebooks/PODA성현

# %%
! pip install pickle5
! pip install tqdm
! pip install ftfy
! pip install regex
! pip install git+https://github.com/openai/CLIP.git
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.1/132.1 kB 7.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pickle5: filename=pickle5-0.0.11-cp310-cp310-linux_x86_64.whl size=255319 sha256=925bb7f80060395690dc7fe0d2e2a1fc2367b4b8c566eb62d9200b8f54b883e7
#   Stored in directory: /root/.cache/pip/wheels/7d/14/ef/4aab19d27fa8e58772be5c71c16add0426acf9e1f64353235c
# Successfully built pickle5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 4.5 MB/s eta 0:00:00
# ...
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-y8vkjbkq
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-y8vkjbkq
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...

# %%
! python3 PIN_aug.py --dataset 'cityscapes' --data_root '/content/drive/MyDrive/PODA/datasets/data/Cityscapes'  --save_dir '/content/drive/MyDrive/성현/datasets/stastics_save(augment)' --resize_feat --total_it 100 --domain_desc 'driving in snow'
# Out:
# 2024-07-24 08:43:33.093698: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-24 08:43:33.093743: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-24 08:43:33.095132: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-24 08:43:33.102723: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
! python3 main.py --dataset 'cityscapes' --data_root '/content/drive/MyDrive/Colab Notebooks/PODA/datasets/data/Cityscapes' --ckpt '/content/drive/MyDrive/Colab Notebooks/PODA/CS_source.pth' --batch_size 8 --lr 0.01 --ckpts_path adapted --freeze_BB --train_aug --total_itrs 2000  --path_mu_sig '/content/drive/MyDrive/Colab Notebooks/PODA성현/save/stastics_save(augment)1'
# Out:
# 2024-07-25 07:27:40.320687: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-25 07:27:40.320739: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-25 07:27:40.322166: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-25 07:27:40.329570: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
! python3 main.py --dataset 'ACDC' --data_root '/content/drive/MyDrive/Colab Notebooks/PODA/datasets/data/ACDC' --ckpt '/content/drive/MyDrive/Colab Notebooks/PODA성현/adapted/adapted_deeplabv3plus_resnet_clip_cityscapes.pth' --test_only --val_batch_size 1 --ACDC_sub 'snow'
# Out:
# 2024-07-25 08:34:22.255736: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-25 08:34:22.255796: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-25 08:34:22.357419: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-25 08:34:22.562540: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
! python3 main.py --dataset 'ACDC' --data_root '/content/drive/MyDrive/Colab Notebooks/PODA/datasets/data/ACDC' --ckpt '/content/drive/MyDrive/Colab Notebooks/PODA성현/adapted/adapted_deeplabv3plus_resnet_clip_cityscapes.pth' --test_only --val_batch_size 1 --ACDC_sub 'rain'
# Out:
# 2024-07-25 08:35:31.441019: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-25 08:35:31.441075: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-25 08:35:31.442679: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-25 08:35:31.450929: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
! python3 main.py --dataset 'ACDC' --data_root '/content/drive/MyDrive/Colab Notebooks/PODA/datasets/data/ACDC' --ckpt '/content/drive/MyDrive/Colab Notebooks/PODA성현/adapted/adapted_deeplabv3plus_resnet_clip_cityscapes.pth' --test_only --val_batch_size 1 --ACDC_sub 'night'
# Out:
# 2024-07-25 08:36:31.008660: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-25 08:36:31.008718: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-25 08:36:31.013579: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-25 08:36:31.025825: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
