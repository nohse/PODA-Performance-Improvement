# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/PODA성현
# Out:
# /content/drive/MyDrive/Colab Notebooks/PODA성현

# %%
! pip install pickle5
! pip install tqdm
! pip install ftfy
! pip install regex
! pip install git+https://github.com/openai/CLIP.git
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.1/132.1 kB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pickle5: filename=pickle5-0.0.11-cp310-cp310-linux_x86_64.whl size=255311 sha256=54a4ff108bdfc7b44d200bb1b3ad9378ad530dd795d32c941fd56bb7d4584353
#   Stored in directory: /root/.cache/pip/wheels/7d/14/ef/4aab19d27fa8e58772be5c71c16add0426acf9e1f64353235c
# Successfully built pickle5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 3.7 MB/s eta 0:00:00
# ...
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-7jlhnihp
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-7jlhnihp
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...

# %%
! python PIN_aug.py \
  --dataset 'cityscapes' \
  --data_root '/content/drive/MyDrive/Colab Notebooks/PODA/datasets/data/Cityscapes' \
  --save_dir '/content/drive/MyDrive/Colab Notebooks/PODA성현/save/stastics_save(uniformaugment1)' \
  --resize_feat \
  --total_it 100 \
  --domain_desc 'driving in snow'
# Out:
# 2024-07-31 07:24:06.026803: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-31 07:24:06.026857: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-31 07:24:06.028203: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-31 07:24:06.035343: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
! python main.py \
  --dataset 'cityscapes' \
  --data_root '/content/drive/MyDrive/Colab Notebooks/PODA/datasets/data/Cityscapes' \
  --ckpt '/content/drive/MyDrive/Colab Notebooks/PODA/CS_source.pth' \
  --batch_size 8 \
  --lr 0.01 \
  --ckpts_path adapted \
  --freeze_BB \
  --train_aug \
  --total_itrs 2000  \
  --path_mu_sig '/content/drive/MyDrive/Colab Notebooks/PODA성현/save/stastics_save(uniformaugment1)'
# Out:
# 2024-07-31 09:06:42.781486: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-31 09:06:42.781537: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-31 09:06:42.783117: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-31 09:06:42.791197: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
! python main.py \
  --dataset 'ACDC' \
  --data_root '/content/drive/MyDrive/Colab Notebooks/PODA/datasets/data/ACDC' \
  --ckpt '/content/drive/MyDrive/Colab Notebooks/PODA성현/adapted/adapted_deeplabv3plus_resnet_clip_cityscapes.pth' \
  --test_only \
  --val_batch_size 1 \
  --ACDC_sub 'snow'
# Out:
# 2024-07-31 10:08:43.421979: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-31 10:08:43.422035: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-31 10:08:43.511057: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-31 10:08:43.747404: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
! python main.py \
  --dataset 'ACDC' \
  --data_root '/content/drive/MyDrive/Colab Notebooks/PODA/datasets/data/ACDC' \
  --ckpt '/content/drive/MyDrive/Colab Notebooks/PODA성현/adapted/adapted_deeplabv3plus_resnet_clip_cityscapes.pth' \
  --test_only \
  --val_batch_size 1 \
  --ACDC_sub 'rain'
# Out:
# 2024-07-31 10:09:46.828516: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-31 10:09:46.828571: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-31 10:09:46.830067: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-31 10:09:46.837165: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
! python main.py \
  --dataset 'ACDC' \
  --data_root '/content/drive/MyDrive/Colab Notebooks/PODA/datasets/data/ACDC' \
  --ckpt '/content/drive/MyDrive/Colab Notebooks/PODA성현/adapted/adapted_deeplabv3plus_resnet_clip_cityscapes.pth' \
  --test_only \
  --val_batch_size 1 \
  --ACDC_sub 'night'
# Out:
# 2024-07-31 10:10:44.965310: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-31 10:10:44.965376: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-31 10:10:44.967414: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-31 10:10:44.979110: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
! python main.py \
  --dataset 'ACDC' \
  --data_root '/content/drive/MyDrive/Colab Notebooks/PODA/datasets/data/ACDC' \
  --ckpt '/content/drive/MyDrive/Colab Notebooks/PODA성현/adapted/adapted_deeplabv3plus_resnet_clip_cityscapes(0.5Loss).pth' \
  --test_only \
  --val_batch_size 1 \
  --ACDC_sub 'snow'
# Out:
# 2024-07-20 08:30:25.406927: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-20 08:30:25.407081: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-20 08:30:25.409394: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-20 08:30:25.421548: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
