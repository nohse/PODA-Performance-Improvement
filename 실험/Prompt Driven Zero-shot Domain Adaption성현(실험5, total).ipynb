# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/성현/PODA
# Out:
# /content/drive/MyDrive/성현/PODA

# %%
! pip install pickle5
! pip install tqdm
! pip install ftfy
! pip install regex
! pip install git+https://github.com/openai/CLIP.git
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.1/132.1 kB 11.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pickle5: filename=pickle5-0.0.11-cp310-cp310-linux_x86_64.whl size=255316 sha256=93296b20227b8fac638c761b2558fac01f7d9a9ea8acca039af876604364ad2a
#   Stored in directory: /root/.cache/pip/wheels/7d/14/ef/4aab19d27fa8e58772be5c71c16add0426acf9e1f64353235c
# Successfully built pickle5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 5.1 MB/s eta 0:00:00
# ...
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-xtpq4d60
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-xtpq4d60
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...

# %%
! python3 PIN_aug.py --dataset 'cityscapes' --data_root '/content/drive/MyDrive/PODA/datasets/data/Cityscapes'  --save_dir '/content/drive/MyDrive/성현/datasets/stastics_save(total+augment)' --resize_feat --total_it 100
# Out:
# 2024-08-05 09:48:55.430482: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-05 09:48:55.450522: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-05 09:48:55.456569: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-05 09:48:55.471135: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
! python3 main.py --dataset 'cityscapes' --data_root '/content/drive/MyDrive/PODA/datasets/data/Cityscapes' --ckpt '/content/drive/MyDrive/PODA/CS_source.pth' --batch_size 8 --lr 0.01 --ckpts_path adapted --freeze_BB --train_aug --total_itrs 2000  --path_mu_sig '/content/drive/MyDrive/성현/datasets/stastics_save(total+augment)'
# Out:
# 2024-08-05 12:18:50.552599: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-05 12:18:50.572378: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-05 12:18:50.578554: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-05 12:18:50.594045: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
! python3 main.py --dataset 'ACDC' --data_root '/content/drive/MyDrive/PODA/datasets/data/ACDC' --ckpt '/content/drive/MyDrive/성현/PODA/adapted/adapted_deeplabv3plus_resnet_clip_cityscapes.pth' --test_only --val_batch_size 1 --ACDC_sub 'snow'
# Out:
# 2024-08-05 12:54:46.315849: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-05 12:54:46.337247: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-05 12:54:46.343942: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-05 12:54:46.359887: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
! python3 main.py --dataset 'ACDC' --data_root '/content/drive/MyDrive/PODA/datasets/data/ACDC' --ckpt '/content/drive/MyDrive/성현/PODA/adapted/adapted_deeplabv3plus_resnet_clip_cityscapes.pth' --test_only --val_batch_size 1 --ACDC_sub 'rain'
# Out:
# 2024-08-05 12:56:07.780393: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-05 12:56:07.800151: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-05 12:56:07.806261: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-05 12:56:07.820835: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
! python3 main.py --dataset 'ACDC' --data_root '/content/drive/MyDrive/PODA/datasets/data/ACDC' --ckpt '/content/drive/MyDrive/성현/PODA/adapted/adapted_deeplabv3plus_resnet_clip_cityscapes.pth' --test_only --val_batch_size 1 --ACDC_sub 'night'
# Out:
# 2024-08-05 12:57:18.004021: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-05 12:57:18.023798: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-05 12:57:18.030064: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-05 12:57:18.044618: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
